# %% [markdown]
# <a href="https://colab.research.google.com/github/AtharvaJ-236/Data-Science/blob/main/DS_Prac6_Multiple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-71b30018-d661-40c7-898e-eb00e33f220c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-71b30018-d661-40c7-898e-eb00e33f220c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('Fifa_world_cup_matches.csv')
df.head()
# Out:
#            team1         team2 possession team1 possession team2  \
# 0          QATAR       ECUADOR              42%              50%
# 1        ENGLAND          IRAN              72%              19%
# 2        SENEGAL   NETHERLANDS              44%              45%
# 3  UNITED STATES         WALES              51%              39%
# 4      ARGENTINA  SAUDI ARABIA              64%              24%
#
#   possession in contest  number of goals team1  number of goals team2  \
# 0                    8%                      0                      2
# 1                    9%                      6                      2
# 2                   11%                      0                      2
# 3                   10%                      1                      1
# 4                   12%                      1                      2
#
#           date     hour category  ...  penalties scored team1  \
# 0  20 NOV 2022  17 : 00  Group A  ...                       0
# ...

# %%
df.describe()
# Out:
#        number of goals team1  number of goals team2  total attempts team1  \
# count              64.000000              64.000000             64.000000
# mean                1.578125               1.109375             11.140625
# std                 1.551289               1.055856              4.972519
# min                 0.000000               0.000000              2.000000
# 25%                 0.000000               0.000000              8.000000
# 50%                 1.000000               1.000000             10.000000
# 75%                 2.000000               2.000000             14.000000
# max                 7.000000               4.000000             25.000000
#
#        total attempts team2  conceded team1  conceded team2  \
# count             64.000000       64.000000       64.000000
# mean              11.281250        1.109375        1.578125
# std                5.807682        1.055856        1.551289
# ...

# %%
plt.title('Team1 Total Attempts Distribution')
sns.histplot(df['total attempts team1'], kde=True)
plt.xlabel('Total Attempts – Team 1')
plt.show()

# %%
plt.scatter(df['total attempts team1'], df['total attempts team2'])
plt.title('Team1 vs Team2 Attempts')
plt.xlabel('Total Attempts – Team 1')
plt.ylabel('Total Attempts – Team 2')
plt.show()

# %%
# Independent Variables (X)
X = df[
    [
     'total attempts team1',
     'number of goals team1',
     'goal inside the penalty area team1',
     'goal outside the penalty area team1',
     'on target attempts team1'
    ]
].values

# Dependent Variable (y)
y = df['total attempts team2'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=0
)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
np.set_printoptions(precision=2)

result = np.concatenate(
    (y_pred.reshape(len(y_pred),1),
     y_test.reshape(len(y_test),1)),
    axis=1
)

result
# Out:
# array([[10.98, 12.  ],
#        [ 5.82,  8.  ],
#        [13.28, 32.  ],
#        [ 8.16, 13.  ],
#        [12.56, 17.  ],
#        [12.84, 15.  ],
#        [ 5.08, 10.  ],
#        [11.52, 15.  ],
#        [ 7.37,  9.  ],
#        [ 9.  ,  7.  ],
#        [ 5.82, 10.  ],
#        [ 9.38,  9.  ],
#        [11.85, 21.  ]])

# %%
# Show coefficients for each input feature
for col, coef in zip(
    [
     'total attempts team1',
     'number of goals team1',
     'goal inside the penalty area team1',
     'goal outside the penalty area team1',
     'on target attempts team1'
    ],
    regressor.coef_
):
    print(f"{col} --> {coef}")
# Out:
# total attempts team1 --> -0.5736873225418541
# number of goals team1 --> -6.285452895101136
# goal inside the penalty area team1 --> 5.884879114618871
# goal outside the penalty area team1 --> 1.9711779370857956
# on target attempts team1 --> 0.41878457417085

# %%
print("Intercept:", regressor.intercept_)
# Out:
# Intercept: 16.153889507810398

# %%
example_input = [[6, 9, 7, 8, 3]]

predicted_attempts = regressor.predict(example_input)

print("Predicted Team2 attempts:", predicted_attempts[0])
# Out:
# Predicted Team2 attempts: 14.36262053818006
